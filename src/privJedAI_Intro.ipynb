# %% [markdown]
# # Introduction to privJedAI
#
# This notebook will guide you throughout all the possible methods and how to use them by our open-source library privJedAI.

# %%
# %pip install -e ..
# Out:
# Obtaining file:///home/lefteris/privJedAI
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: bitarray in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from privJedAI==0.0.3) (3.8.1)
# Requirement already satisfied: faiss-cpu in /home/lefteris/.local/lib/python3.10/site-packages (from privJedAI==0.0.3) (1.13.2)
# Requirement already satisfied: matplotlib in /home/lefteris/.local/lib/python3.10/site-packages (from privJedAI==0.0.3) (3.10.9)
# Requirement already satisfied: Metafone in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from privJedAI==0.0.3) (0.5)
# Requirement already satisfied: numexpr in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from privJedAI==0.0.3) (2.14.1)
# Requirement already satisfied: numpy in /home/lefteris/.local/lib/python3.10/site-packages (from privJedAI==0.0.3) (2.2.6)
# Requirement already satisfied: openfhe in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from privJedAI==0.0.3) (1.5.0.0.22.4)
# Requirement already satisfied: ordered_set in /home/lefteris/.local/lib/python3.10/site-packages (from privJedAI==0.0.3) (4.1.0)
# Requirement already satisfied: pandas in /home/lefteris/.local/lib/python3.10/site-packages (from privJedAI==0.0.3) (2.3.3)
# Requirement already satisfied: scipy in /home/lefteris/.local/lib/python3.10/site-packages (from privJedAI==0.0.3) (1.15.3)
# Requirement already satisfied: seaborn in /home/lefteris/.local/lib/python3.10/site-packages (from privJedAI==0.0.3) (0.13.2)
# Requirement already satisfied: tqdm in /home/lefteris/.local/lib/python3.10/site-packages (from privJedAI==0.0.3) (4.67.3)
# Requirement already satisfied: ray in /home/lefteris/.local/lib/python3.10/site-packages (from privJedAI==0.0.3) (2.55.1)
# Requirement already satisfied: ipywidgets in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from privJedAI==0.0.3) (8.1.8)
# Requirement already satisfied: numba in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from privJedAI==0.0.3) (0.65.0)
# Requirement already satisfied: packaging in /home/lefteris/.local/lib/python3.10/site-packages (from faiss-cpu->privJedAI==0.0.3) (26.2)
# Requirement already satisfied: comm>=0.1.3 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipywidgets->privJedAI==0.0.3) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipywidgets->privJedAI==0.0.3) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipywidgets->privJedAI==0.0.3) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipywidgets->privJedAI==0.0.3) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipywidgets->privJedAI==0.0.3) (3.0.16)
# Requirement already satisfied: decorator in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/lefteris/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (2.20.0)
# Requirement already satisfied: stack-data in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/lefteris/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.6 in /home/lefteris/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (4.15.0)
# Requirement already satisfied: pexpect>4.3 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (4.9.0)
# Requirement already satisfied: wcwidth in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (0.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lefteris/.local/lib/python3.10/site-packages (from matplotlib->privJedAI==0.0.3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/lefteris/.local/lib/python3.10/site-packages (from matplotlib->privJedAI==0.0.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lefteris/.local/lib/python3.10/site-packages (from matplotlib->privJedAI==0.0.3) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lefteris/.local/lib/python3.10/site-packages (from matplotlib->privJedAI==0.0.3) (1.5.0)
# Requirement already satisfied: pillow>=8 in /home/lefteris/.local/lib/python3.10/site-packages (from matplotlib->privJedAI==0.0.3) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/lefteris/.local/lib/python3.10/site-packages (from matplotlib->privJedAI==0.0.3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lefteris/.local/lib/python3.10/site-packages (from matplotlib->privJedAI==0.0.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->privJedAI==0.0.3) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from numba->privJedAI==0.0.3) (0.47.0)
# Requirement already satisfied: pytz>=2020.1 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from pandas->privJedAI==0.0.3) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/lefteris/.local/lib/python3.10/site-packages (from pandas->privJedAI==0.0.3) (2026.2)
# Requirement already satisfied: click>=7.0 in /home/lefteris/.local/lib/python3.10/site-packages (from ray->privJedAI==0.0.3) (8.3.3)
# Requirement already satisfied: filelock in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ray->privJedAI==0.0.3) (3.25.2)
# Requirement already satisfied: jsonschema in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ray->privJedAI==0.0.3) (4.26.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/lefteris/.local/lib/python3.10/site-packages (from ray->privJedAI==0.0.3) (1.1.2)
# Requirement already satisfied: protobuf>=3.20.3 in /home/lefteris/.local/lib/python3.10/site-packages (from ray->privJedAI==0.0.3) (7.34.1)
# Requirement already satisfied: pyyaml in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ray->privJedAI==0.0.3) (6.0.3)
# Requirement already satisfied: requests in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from ray->privJedAI==0.0.3) (2.33.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from jsonschema->ray->privJedAI==0.0.3) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from jsonschema->ray->privJedAI==0.0.3) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from jsonschema->ray->privJedAI==0.0.3) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from jsonschema->ray->privJedAI==0.0.3) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from requests->ray->privJedAI==0.0.3) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from requests->ray->privJedAI==0.0.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from requests->ray->privJedAI==0.0.3) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from requests->ray->privJedAI==0.0.3) (2026.2.25)
# Requirement already satisfied: executing>=1.2.0 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (3.0.1)
# Requirement already satisfied: pure_eval in /home/conda/miniconda3/envs/privjedai-test2/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->privJedAI==0.0.3) (0.2.3)
# Building wheels for collected packages: privJedAI
#   Building editable for privJedAI (pyproject.toml) ... done
#   Created wheel for privJedAI: filename=privjedai-0.0.3-0.editable-py3-none-any.whl size=8913 sha256=2431a10718f8a765be586d30cd78ce820bcce20a9e37c9a40552fddd5133ccbe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6ppgw4fx/wheels/3d/c5/59/5bd4e07c02455ba64adf12d849d7aadca35951ed88bc75a965
# Successfully built privJedAI
# Installing collected packages: privJedAI
#   Attempting uninstall: privJedAI
#     Found existing installation: privJedAI 0.0.3
#     Can't uninstall 'privJedAI'. No files were found to uninstall.
# Successfully installed privJedAI-0.0.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Dataset Abt Buy Clean

# %% [markdown]
# Below we load the two different datasets and their ground truth. privJedAI needs the indices of the pairs for each dataset and not their id. Here we present also how to preprocess a ground truth that contains id1-id2 pairs to index1-index2 pairs.

# %%
import pandas as pd

def load_dataset(path, file, sep):
    return pd.read_csv(f"../{path}/{file}.csv", sep=sep)

def load_ground_truth(path, sep, d1, d2): 
    gt = pd.read_csv(f'../{path}/gtclean.csv' , sep=sep)
    df_a = d1.reset_index().rename(columns={"index": "index_A"})
    df_b = d2.reset_index().rename(columns={"index": "index_B"})

    df_a = df_a[["index_A", "id"]]
    df_b = df_b[["index_B", "id"]]

    gt_index = gt.merge(left_on='D1', right=df_a, right_on='id')

    gt_index = gt_index.drop(columns=['id', 'D1'])
    gt_index.columns = ['D2', 'D1']

    gt_index = gt_index.merge(left_on='D2', right=df_b, right_on='id')
    gt_index = gt_index.drop(columns=['id', 'D2'])
    gt_index.columns = ['D1', 'D2']
    d1 = d1.astype(str)
    d2 = d2.astype(str)

    return gt_index, d1, d2

# %%
DIR = "D2"
PATH = f"data/ccer/{DIR}"
FILE = 'abtclean'
FILE2 = 'buyclean'
attributes = ['name']
SEP = "|"

abt = load_dataset(PATH, FILE, SEP)
buy = load_dataset(PATH, FILE2, SEP)

gt_index, abt, buy = load_ground_truth(PATH, SEP, abt, buy)

# %% [markdown]
# ## Encode data and build bloom filters

# %% [markdown]
# Each party agree in an exact configuration and then encode locally their data.
# Those encoded data are then shared to a third party to proceed with record linkage.

# %%
from privjedai.encoder import BloomFilterConfig, BloomEncodedData, BloomFilter

bloom_filter_configuration = {
    "size" : 1024,
    "offset" : 0,
    "num_hashes" : 15,
    "hashing_type": "salted_qgrams",
    "salt" : "",
    "attributes": ['name'],
    "qgrams": 4
}

# %% [markdown]
# # Abt Owner Encodes Dataset

# %%
config = BloomFilterConfig(**bloom_filter_configuration)
bloom_generator = BloomFilter(config)

## The two parties encode their datasets and save them to disk.
## The encoded datasets are then shared with the other party and used for the matching process.
encoded_d1 = bloom_generator.encode(abt)
encoded_d1.to_file(f"dataset_1.pkl")
# Out:
# Encoding Data with attributes ['name']:   0%|          | 0/1076 [00:00<?, ?it/s]

# %%
encoded_d1.metadata.attributes
# Out:
# ['name']

# %% [markdown]
# ## Buy Owner Encodes Dataset

# %%
bloom_generator_buy = BloomFilter(config)
encoded_d2 = bloom_generator_buy.encode(buy)
encoded_d2.to_file(f"dataset_2.pkl")
# Out:
# Encoding Data with attributes ['name']:   0%|          | 0/1064 [00:00<?, ?it/s]

# %% [markdown]
# ## Trusted Third Party: Linking Phase

# %%
# Third party loads the encoded datasets and performs the matching process.
encoded_data = BloomEncodedData.from_file("dataset_1.pkl", "dataset_2.pkl")


# Ground truth must be explicitly set for the evaluation process. 
# This is done by providing the indices of the matching records in the original datasets.r
encoded_data.set_ground_truth(gt_index)

# %% [markdown]
# ## Blocking with privJedAI
#
# In privJedAI we have 2 different implementations of Hamming LSH and a FAISS implementation.

# %% [markdown]
# ### BitBlocker

# %%
from privjedai.blocking import BitBlocker



configuration = BitBlocker.auto_psi_lambda(
    encoded_data=encoded_data,
    threshold=0.3,
    delta=0.1,
    max_lambda_=200
)



print(configuration)

blocker = BitBlocker(**configuration,
            seed = 42)

blocks = blocker.build_blocks(encoded_data=encoded_data)


ev = blocker.evaluate(blocks)

print(f"candidate pairs : {ev['True Positives'] + ev['False Positives']}")
# Out:
# {'psi': 13, 'lambda_': 165}
# ***************************************************************************************************************************
#                                          Method:  BitBlocker
# ***************************************************************************************************************************
# Method name: BitBlocker
# Parameters:
# Runtime: 3.5528 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:      1.28%
# 	Recall:        91.07%
# 	F1-score:       2.53%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# candidate pairs : 75549

# %%
blocker.evaluate_blocks()
# Out:
# ***************************************************************************************************************************
#                                          Method:  BitBlocker
# ***************************************************************************************************************************
# Method name: BitBlocker
# Parameters:
# Runtime: 3.5528 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:      0.74%
# 	Recall:        91.07%
# 	F1-score:       1.46%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# {'Precision %': 0.7356402119615554,
#  'Recall %': 91.07142857142857,
#  'F1 %': 1.459491211422891,
#  'True Positives': 969,
#  'False Positives': 130753,
#  'True Negatives': 981,
#  'False Negatives': 95}

# %%
from privjedai.blocking import LSHBlocker

blocker = LSHBlocker(psi = 8,
            lambda_ = 24,
            seed = 42,
            prune_ratio = 0.8)

blocks = blocker.build_blocks(encoded_data=encoded_data)
_ = blocker.evaluate(blocks)
# Out:
# ***************************************************************************************************************************
#                                          Method:  LSHBlocker
# ***************************************************************************************************************************
# Method name: LSHBlocker
# Parameters:
# 	psi: 8
# 	lambda_: 24
# 	prune_ratio: 0.8
# 	prune_sample: 1000
# 	seed: 42
# Runtime: 1.1266 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:      0.09%
# 	Recall:        91.07%
# 	F1-score:       0.18%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### FAISSBlocking

# %%
from privjedai.blocking import FAISSBlocking

blocker = FAISSBlocking(index_type='flat')

blocks = blocker.build_blocks(encoded_data=encoded_data, top_k=20)
_ = blocker.evaluate(blocks)
# Out:
# ***************************************************************************************************************************
#                                          Method:  FAISS Blocking
# ***************************************************************************************************************************
# Method name: FAISS Blocking
# Parameters:
# Runtime: 0.2181 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:      4.87%
# 	Recall:        97.37%
# 	F1-score:       9.27%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Meta-blocking Techniques
#
# Those above are all standard blocking techniques. privJedAI also implements meta-blocking methods. It leverages comparison cleaning methods from ER and implements them for bitarrays. A block is a set of adjacent active bits of a bitarray.

# %%
from privjedai.comparison_cleaning import ( 
    WeightedEdgePruning,
    WeightedNodePruning,
    CardinalityEdgePruning,
    CardinalityNodePruning
)

cc = CardinalityEdgePruning(weighting_scheme='CN-CBS')

cc_blocks = cc.process(encoded_data, adjacent_bits=2)

_ = cc.evaluate(cc_blocks)
# Out:
# ***************************************************************************************************************************
#                                          Method:  Cardinality Edge Pruning
# ***************************************************************************************************************************
# Method name: Cardinality Edge Pruning
# Parameters:
# 	Node centric: False
# 	Weighting scheme: CN-CBS
# Runtime: 3.0770 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:      0.31%
# 	Recall:        98.87%
# 	F1-score:       0.61%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Matching
#
# After filtering our datasets we can use a similarity function and match the possible candidate pairs.

# %%
from privjedai.matching import Matcher
import numpy as np
matcher = Matcher(batch_size = 10_000,
                  threshold = 0.6,
                  metric='dice')

matches = matcher.predict(encoded_data=encoded_data, blocks=blocks)

_ = matcher.evaluate(matches)
# Out:
# Predicting batches:   0%|          | 0/3 [00:00<?, ?it/s]
# ***************************************************************************************************************************
#                                          Method:  Matcher
# ***************************************************************************************************************************
# Method name: Matcher
# Parameters:
# 	batch_size: 10000
# 	threshold: 0.6
# 	metric: dice
# 	attributes: None
# Runtime: 0.2279 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:     13.23%
# 	Recall:        89.76%
# 	F1-score:      23.05%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Clustering
#
# To eliminate possible conflicts on the matching pairs, we provide multiple clustering techniques.

# %%
from privjedai.clustering import KiralyMSMApproximateClustering

clusterer = KiralyMSMApproximateClustering()

clusters = clusterer.process(matches, encoded_data=encoded_data)

_ = clusterer.evaluate(clusters)
# Out:
# ***************************************************************************************************************************
#                                          Method:  Kiraly MSM Approximate Clustering
# ***************************************************************************************************************************
# Method name: Kiraly MSM Approximate Clustering
# Parameters:
# 	Similarity Threshold: 0.1
# Runtime: 0.0564 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:      0.00%
# 	Recall:         0.00%
# 	F1-score:       0.00%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# /home/lefteris/privJedAI/src/privjedai/evaluation.py:113: Warning: Evaluation: No matches found
#   warn("Evaluation: No matches found", Warning)

# %% [markdown]
# ## Additonal Features

# %% [markdown]
# Concurrent matching using ray

# %%
from privjedai.ray.matching import Matcher
import numpy as np
matcher = Matcher(batch_size = 10_000,
                  threshold = 0.6,
                  metric='dice',
                  workers=10)

matches = matcher.predict(encoded_data=encoded_data, blocks=blocks)

_ = matcher.evaluate(matches)
# Out:
# /home/lefteris/.local/lib/python3.10/site-packages/ray/_private/worker.py:2051: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# Predicting batches:   0%|          | 0/3 [00:00<?, ?it/s]
# ***************************************************************************************************************************
#                                          Method:  Matcher
# ***************************************************************************************************************************
# Method name: Matcher
# Parameters:
# 	batch_size: 10000
# 	threshold: 0.6
# 	metric: dice
# 	attributes: None
# Runtime: 0.9484 seconds
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Performance:
# 	Precision:     13.23%
# 	Recall:        89.76%
# 	F1-score:      23.05%
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## GPU-Accelaration

# %%
from privjedai.gpu.matching import Matcher
from privjedai.gpu.clustering import KiralyMSMApproximateClustering

matcher = Matcher(batch_size = 10_000,
                  threshold = 0.6,
                  metric='dice',
                  )

matches = matcher.predict(encoded_data=encoded_data, blocks=blocks)

_ = matcher.evaluate(matches, verbose=True)

clusterer = KiralyMSMApproximateClustering()
clusters = clusterer.process(matches, encoded_data=encoded_data)
_ = clusterer.evaluate(clusters)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from privjedai.gpu.matching import Matcher
#       2 from privjedai.gpu.clustering import KiralyMSMApproximateClustering
#       4 matcher = Matcher(batch_size = 10_000,
#       5                   threshold = 0.6,
#       6                   metric='dice',
#       7                   )
#
# File ~/privJedAI/src/privjedai/gpu/matching.py:8
#       6 from dataclasses import dataclass
#       7 import numpy as np
# ----> 8 import cupy as cp
#       9 from ordered_set import OrderedSet
#      10 from tqdm.auto import tqdm
#
# ModuleNotFoundError: No module named 'cupy'
